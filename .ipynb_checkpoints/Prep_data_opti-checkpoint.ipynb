# %%
import pandas as pd
import numpy as np
import random
from sklearn import preprocessing
import matplotlib.pyplot as plt
from datetime import date

# %%
data = pd.read_csv("data/df_new.csv")

# %% [markdown]
# ### 1. Split data for optim part

# %%
df_opti = data[data.ScheduledTime >= "2016-05-30"]
df_opti = df_opti[df_opti.ScheduledTime <= "2016-06-05"]

# %% [markdown]
# df_opti.to_csv("data/data_opti.csv", index = False)

# %%
df_pred = data[data.ScheduledTime < "2016-05-30"]

# %% [markdown]
# df_pred.to_csv("data/data_pred.csv", index = False)

# %% [markdown]
# ### 2. Select one clinic and nb doctors

# %% [markdown]
# Select clinic with enough appointments and high no show rate : 5800 appointments and 21% no show for Maria Ortiz

# %%
neigh = "MARIA ORTIZ"

# %% [markdown]
# n_doc = np.floor(len(df_opti[df_opti.Neighbourhood == neigh])/(5*10))

# %%
n_doc = 22

# %%
df_pred_c = df_pred[df_pred.Neighbourhood == neigh]

# %%
df_opti_c = df_opti[df_opti.Neighbourhood == neigh]

# %% [markdown]
# ### 3. Get prebooked slots

# %%
df_pred_c = df_pred_c[df_pred_c.AppointmentTime >= "2016-05-30"]
df_pred_c = df_pred_c[df_pred_c.AppointmentTime <= "2016-06-05"]
df_pred_c['AppointmentTime']= pd.to_datetime(df_pred_c['AppointmentTime'])
df_pred_c.AppointmentTime = df_pred_c.AppointmentTime.dt.tz_localize(None)
df_pred_c["slot"] = df_pred_c.apply(
    lambda row: (row.AppointmentTime - pd.to_datetime("2016-05-30")).days*10 + random.randint(0,9), axis=1)
df_pred_c.to_csv("data/pred_Maria.csv")

# %%
df_opti_c = df_opti_c[df_opti_c.AppointmentTime >= "2016-05-30"]
df_opti_c = df_opti_c[df_opti_c.AppointmentTime <= "2016-06-05"]
df_opti_c.to_csv("data/opti_Maria.csv")

# %%
df_opti_c
# Out:
#         PatientId  AppointmentID Gender              ScheduledTime  \
# 3250        23306          95781      F  2016-05-31 11:47:10+00:00
# 3266        38700          93903      F  2016-05-30 19:25:44+00:00
# 3294        41570          94241      F  2016-05-31 07:18:33+00:00
# 3296         9842          91782      F  2016-05-30 09:23:34+00:00
# 3297        40527          91640      F  2016-05-30 09:01:04+00:00
# ...           ...            ...    ...                        ...
# 110499      59334          98085      F  2016-06-01 09:42:56+00:00
# 110501       5697          98260      M  2016-06-01 10:19:12+00:00
# 110505      37540          98410      F  2016-06-01 10:45:50+00:00
# 110506       9273          98531      M  2016-06-01 11:09:20+00:00
# 110508      46559          98062      F  2016-06-01 09:41:00+00:00
#
#                   AppointmentTime  Age Neighbourhood  Scholarship  \
# 3250    2016-05-31 23:59:59+00:00   49   MARIA ORTIZ            0
# 3266    2016-05-31 23:59:59+00:00   24   MARIA ORTIZ            0
# 3294    2016-05-31 23:59:59+00:00   42   MARIA ORTIZ            0
# 3296    2016-05-30 23:59:59+00:00   52   MARIA ORTIZ            0
# 3297    2016-05-30 23:59:59+00:00    2   MARIA ORTIZ            0
# ...                           ...  ...           ...          ...
# 110499  2016-06-01 23:59:59+00:00   66   MARIA ORTIZ            0
# 110501  2016-06-01 23:59:59+00:00   44   MARIA ORTIZ            0
# 110505  2016-06-01 23:59:59+00:00   55   MARIA ORTIZ            0
# 110506  2016-06-01 23:59:59+00:00    5   MARIA ORTIZ            0
# 110508  2016-06-01 23:59:59+00:00   59   MARIA ORTIZ            0
#
#         Hipertension  Diabetes  ...  AppointmentDay  AppointmentMonth  \
# 3250               0         0  ...              31                 5
# 3266               0         0  ...              31                 5
# 3294               0         0  ...              31                 5
# 3296               0         0  ...              30                 5
# 3297               0         0  ...              30                 5
# ...              ...       ...  ...             ...               ...
# 110499             1         1  ...               1                 6
# 110501             0         0  ...               1                 6
# 110505             0         0  ...               1                 6
# 110506             0         0  ...               1                 6
# 110508             0         0  ...               1                 6
#
#         AppointmentYear  AppointmentWeekDay  AppointmentHourRandom  \
# 3250               2016                   1                     16
# 3266               2016                   1                     11
# 3294               2016                   1                     13
# 3296               2016                   0                     15
# 3297               2016                   0                      9
# ...                 ...                 ...                    ...
# 110499             2016                   2                     18
# 110501             2016                   2                     12
# 110505             2016                   2                     11
# 110506             2016                   2                     16
# 110508             2016                   2                     12
#
#         Availability_0  Availability_1  Availability_2  Availability_3  \
# 3250                37              46              28              25
# 3266                57              42              58              16
# 3294                 5              57              56              29
# 3296                34              28               3              16
# 3297                51              32              46              12
# ...                ...             ...             ...             ...
# 110499              15              45              47              40
# 110501              29              28              26              40
# 110505              57              19              52              54
# 110506              16              36              30               9
# 110508              50              20              44              42
#
#         Availability_4
# 3250                 5
# 3266                 7
# 3294                37
# 3296                 1
# 3297                11
# ...                ...
# 110499              18
# 110501              44
# 110505              29
# 110506              26
# 110508              36
#
# [545 rows x 34 columns]

# %% [markdown]
# ### 4. Generate random availability patient

# %%
for i in range(5):
    df_opti_c.loc[:,"Availability_"+str(i)] = [random.randint(0,51) for n in range(len(df_opti_c))]

# %%
df_opti_c.to_csv("data/opti_Maria.csv")

# %%
df_opti_c
# Out:
#         PatientId  AppointmentID Gender              ScheduledTime  \
# 3250        23306          95781      F  2016-05-31 11:47:10+00:00
# 3266        38700          93903      F  2016-05-30 19:25:44+00:00
# 3294        41570          94241      F  2016-05-31 07:18:33+00:00
# 3296         9842          91782      F  2016-05-30 09:23:34+00:00
# 3297        40527          91640      F  2016-05-30 09:01:04+00:00
# ...           ...            ...    ...                        ...
# 110499      59334          98085      F  2016-06-01 09:42:56+00:00
# 110501       5697          98260      M  2016-06-01 10:19:12+00:00
# 110505      37540          98410      F  2016-06-01 10:45:50+00:00
# 110506       9273          98531      M  2016-06-01 11:09:20+00:00
# 110508      46559          98062      F  2016-06-01 09:41:00+00:00
#
#                   AppointmentTime  Age Neighbourhood  Scholarship  \
# 3250    2016-05-31 23:59:59+00:00   49   MARIA ORTIZ            0
# 3266    2016-05-31 23:59:59+00:00   24   MARIA ORTIZ            0
# 3294    2016-05-31 23:59:59+00:00   42   MARIA ORTIZ            0
# 3296    2016-05-30 23:59:59+00:00   52   MARIA ORTIZ            0
# 3297    2016-05-30 23:59:59+00:00    2   MARIA ORTIZ            0
# ...                           ...  ...           ...          ...
# 110499  2016-06-01 23:59:59+00:00   66   MARIA ORTIZ            0
# 110501  2016-06-01 23:59:59+00:00   44   MARIA ORTIZ            0
# 110505  2016-06-01 23:59:59+00:00   55   MARIA ORTIZ            0
# 110506  2016-06-01 23:59:59+00:00    5   MARIA ORTIZ            0
# 110508  2016-06-01 23:59:59+00:00   59   MARIA ORTIZ            0
#
#         Hipertension  Diabetes  ...  AppointmentDay  AppointmentMonth  \
# 3250               0         0  ...              31                 5
# 3266               0         0  ...              31                 5
# 3294               0         0  ...              31                 5
# 3296               0         0  ...              30                 5
# 3297               0         0  ...              30                 5
# ...              ...       ...  ...             ...               ...
# 110499             1         1  ...               1                 6
# 110501             0         0  ...               1                 6
# 110505             0         0  ...               1                 6
# 110506             0         0  ...               1                 6
# 110508             0         0  ...               1                 6
#
#         AppointmentYear  AppointmentWeekDay  AppointmentHourRandom  \
# 3250               2016                   1                     16
# 3266               2016                   1                     11
# 3294               2016                   1                     13
# 3296               2016                   0                     15
# 3297               2016                   0                      9
# ...                 ...                 ...                    ...
# 110499             2016                   2                     18
# 110501             2016                   2                     12
# 110505             2016                   2                     11
# 110506             2016                   2                     16
# 110508             2016                   2                     12
#
#         Availability_0  Availability_1  Availability_2  Availability_3  \
# 3250                40               4              10              43
# 3266                45              12              14               6
# 3294                14              46              50              49
# 3296                39               7              41              38
# 3297                 3              37              36              42
# ...                ...             ...             ...             ...
# 110499              35              49              23              20
# 110501              44              22               8              20
# 110505              32              11               2              29
# 110506              24              12              22              41
# 110508              16               1              16              35
#
#         Availability_4
# 3250                12
# 3266                44
# 3294                15
# 3296                22
# 3297                 3
# ...                ...
# 110499               2
# 110501              17
# 110505               9
# 110506              10
# 110508              26
#
# [545 rows x 34 columns]
